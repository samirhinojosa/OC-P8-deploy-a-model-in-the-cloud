# %% [markdown]
# <div style="display: flex; background-color: #3F579F;">
#     <h1 style="margin: auto; font-weight: bold; padding: 30px 30px 0px 30px; color:#fff;" align="center">Deploy a model in the cloud - P8</h1>
# </div>
# <div style="display: flex; background-color: #3F579F; margin: auto; padding: 5px 30px 0px 30px;" >
#     <h3 style="width: 100%; text-align: center; float: left; font-size: 24px; color:#fff;" align="center">| Notebook - Proof of Concept |</h3>
# </div>
# <div style="display: flex; background-color: #3F579F; margin: auto; padding: 10px 30px 30px 30px;">
#     <h4 style="width: 100%; text-align: center; float: left; font-size: 24px; color:#fff;" align="center">Data Scientist course - OpenClassrooms</h4>
# </div>

# %% [markdown]
# <div style="background-color: #506AB9;" >
#     <h2 style="margin: auto; padding: 20px; color:#fff; ">1. Libraries & static variables</h2>
# </div>

# %%
## General
import os
import io
import numpy as np
import pandas as pd
from PIL import Image, ImageOps
import seaborn as sns
import matplotlib.pyplot as plt

## To connect with S3 files
import botocore.session
import boto3

## Spark
import findspark
findspark.init()
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import (split, col, pandas_udf,
                                   PandasUDFType, udf)
from pyspark.ml.linalg import Vectors, VectorUDT
from pyspark.ml.feature import StandardScaler, PCA

## Tensorflow 
import tensorflow as tf
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array

## Own specific functions 
from functions import *
# Out:
# 2022-03-13 07:18:34.506452: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-13 07:18:34.506488: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
BUCKET = "oc-p8-bucket"
SUBFOLDER = "test/images/"
RESULT = "result"
DUMMY_FILE = "SampleCSVFile_556kb.csv"

# %% [markdown]
# <div style="background-color: #506AB9;" >
#     <h2 style="margin: auto; padding: 20px; color:#fff; ">2. Testing connection to S3</h2>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <p>We are going to print the name of the first 5 elements in the S3.</p>
# </div>

# %%
conn = boto3.client("s3")

# %%
contents = conn.list_objects(Bucket=BUCKET)["Contents"]
for k in list(contents)[:5]:
    print(k["Key"])
# Out:
# SampleCSVFile_556kb.csv
# result/
# result/P7_PCA_result.csv
# result/P7_PCA_result_v2.csv
# test/

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <p>Now, we are going to test whether we can read an image from S3.</p>
# </div>

# %%
test_img = Image.open(
            io.BytesIO(
                conn.get_object(
                    Bucket=BUCKET,
                    Key=list(contents)[7]["Key"])["Body"].read()
                )
    )

test_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=100x100 at 0x7FD8CD591D90>

# %% [markdown]
# <div style="background-color: #506AB9;" >
#     <h2 style="margin: auto; padding: 20px; color:#fff; ">3. Spark session</h2>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <p>Let's setup Spark</p>
# </div>

# %%
session = botocore.session.get_session()
credentials = session.get_credentials()
region = (boto3.session.Session()).region_name

# %%
spark = (
    SparkSession
    .builder
    .appName("P8-FRUITS")
    .getOrCreate()
)

spark
# Out:
# 22/03/13 07:18:38 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 22/03/13 07:18:40 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://ip-172-31-80-208.ec2.internal:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.0.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>P8-FRUITS</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <p>Let's setup the aws information</p>
# </div>

# %%
sc = spark.sparkContext._jsc.hadoopConfiguration()
sc.set("fs.s3a.awsAccessKeyId", credentials.access_key)
sc.set("fs.s3a.awsSecretAccessKey", credentials.secret_key)
sc.set("fs.s3a.impl","org.apache.hadoop.fs.s3a.S3AFileSystem")
sc.set("fs.s3a.impl","org.apache.hadoop.fs.s3native.NativeS3FileSystem")
sc.set("com.amazonaws.services.s3.enableV4", "true")
sc.set("fs.s3a.aws.credentials.provider","org.apache.hadoop.fs.s3a.BasicAWSCredentialsProvider")
sc.set("fs.s3a.endpoint", region + ".amazonaws.com")

# %% [markdown]
# <div style="background-color: #506AB9;" >
#     <h3 style="margin: auto; padding: 20px; color:#fff; ">3.1 Testing connection to S3 with Spark</h3>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <p>Now, we are going to test the connection with Spark to our bucket. To do that, we are going to read a sample csv.</p>
# </div>

# %%
data_location = "s3a://{}/{}".format(BUCKET, DUMMY_FILE)

# %%
df_dummy = spark.read.csv(data_location, header="False", inferSchema=True)
df_dummy = df_dummy.drop("1")

# %%
df_dummy.limit(5).toPandas()
# Out:
#    _c0                                                _c1                 _c2  \
# 0    1   Eldon Base for stackable storage shelf, platinum  Muhammed MacIntyre
# 1    2  "1.7 Cubic Foot Compact ""Cube"" Office Refrig...        Barry French
# 2    3   Cardinal Slant-D� Ring Binder, Heavy Gauge Vinyl        Barry French
# 3    4                                               R380       Clay Rozendal
# 4    5                           Holmes HEPA Air Purifier      Carlos Soltero
#
#    _c3      _c4     _c5    _c6      _c7                             _c8   _c9
# 0    3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 1  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# 2  293    46.71    8.69   2.99  Nunavut  Binders and Binder Accessories  0.39
# 3  483  1198.97  195.99   3.99  Nunavut    Telephones and Communication  0.58
# 4  515    30.94   21.78   5.94  Nunavut                      Appliances   0.5

# %%
df_dummy.printSchema()
# Out:
# root
#  |-- _c0: integer (nullable = true)
#  |-- _c1: string (nullable = true)
#  |-- _c2: string (nullable = true)
#  |-- _c3: string (nullable = true)
#  |-- _c4: string (nullable = true)
#  |-- _c5: string (nullable = true)
#  |-- _c6: string (nullable = true)
#  |-- _c7: string (nullable = true)
#  |-- _c8: string (nullable = true)
#  |-- _c9: string (nullable = true)

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <p>Great!, we can access to S3 from ours Notebook through Spark / Pyspark</p>
# </div>

# %% [markdown]
# <div style="background-color: #506AB9;" >
#     <h3 style="margin: auto; padding: 20px; color:#fff; ">3.2 Testing reading an image from S3 through Spark</h3>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <p>Now, let's try to read an image from the bucket</p>
# </div>

# %%
image = spark.read.format("image").load("s3a://{}/{}".format(BUCKET, list(contents)[7]["Key"]))

# %%
image.printSchema()
# Out:
# root
#  |-- image: struct (nullable = true)
#  |    |-- origin: string (nullable = true)
#  |    |-- height: integer (nullable = true)
#  |    |-- width: integer (nullable = true)
#  |    |-- nChannels: integer (nullable = true)
#  |    |-- mode: integer (nullable = true)
#  |    |-- data: binary (nullable = true)

# %%
image.show()
# Out:
# +--------------------+
# |               image|
# +--------------------+
# |[s3a://oc-p8-buck...|
# +--------------------+

# %%
img = image.first()

# %%
img = np.array(img.asDict()["image"]["data"]).reshape(100, 100, 3)[:, :, ::-1]

# %%
Image.fromarray(img, "RGB")
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FD8CD400850>

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <p>So far, We have access to an image. Let's go to read all images in the bucket.</p>
# </div>

# %% [markdown]
# <div style="background-color: #506AB9;" >
#     <h2 style="margin: auto; padding: 20px; color:#fff; ">3. Reading images with Spark</h2>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <p>To read the images, we will restrict the format only to *.jpg. In addition, we will read all subdirectories in the main directory.</p>
# </div>

# %%
df_images = spark.read.format("binaryfile")\
      .option("recursiveFileLookup", "true")\
      .load("s3a://{}/{}/*".format(BUCKET, SUBFOLDER))

# %%
df_images.printSchema()
# Out:
# root
#  |-- path: string (nullable = true)
#  |-- modificationTime: timestamp (nullable = true)
#  |-- length: long (nullable = true)
#  |-- content: binary (nullable = true)

# %%
df_images.show(5)
# Out:
# +--------------------+-------------------+------+--------------------+
# |                path|   modificationTime|length|             content|
# +--------------------+-------------------+------+--------------------+
# |s3a://oc-p8-bucke...|2022-02-28 09:03:42|  7415|[FF D8 FF E0 00 1...|
# |s3a://oc-p8-bucke...|2022-02-28 09:03:41|  7314|[FF D8 FF E0 00 1...|
# |s3a://oc-p8-bucke...|2022-02-28 09:03:06|  7178|[FF D8 FF E0 00 1...|
# |s3a://oc-p8-bucke...|2022-02-28 09:03:40|  7089|[FF D8 FF E0 00 1...|
# |s3a://oc-p8-bucke...|2022-02-28 09:03:13|  6823|[FF D8 FF E0 00 1...|
# +--------------------+-------------------+------+--------------------+
# only showing top 5 rows

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <p>Let's just save the interested variables for each image.</p>
# </div>

# %%
df_images = df_images.withColumn("category", split(col("path"), "/").getItem(5))
df_images = df_images.select("path", "category", "content")
df_images.printSchema()
# Out:
# root
#  |-- path: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- content: binary (nullable = true)

# %%
df_images.show(5)
# Out:
# +--------------------+----------+--------------------+
# |                path|  category|             content|
# +--------------------+----------+--------------------+
# |s3a://oc-p8-bucke...| Raspberry|[FF D8 FF E0 00 1...|
# |s3a://oc-p8-bucke...| Raspberry|[FF D8 FF E0 00 1...|
# |s3a://oc-p8-bucke...| Raspberry|[FF D8 FF E0 00 1...|
# |s3a://oc-p8-bucke...| Raspberry|[FF D8 FF E0 00 1...|
# |s3a://oc-p8-bucke...|Watermelon|[FF D8 FF E0 00 1...|
# +--------------------+----------+--------------------+
# only showing top 5 rows

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <p>Now, we have only the interested variables of each image.</p>
# </div>

# %% [markdown]
# <div style="background-color: #506AB9;" >
#     <h2 style="margin: auto; padding: 20px; color:#fff; ">4. Preprocessing</h2>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <p>Now, we are going to take the content from an image to show the transformation that we are going to do before making the feature extraction</p>
# </div>

# %%
image_content = df_images.collect()[0][2]

# %%
image_content = Image.open(io.BytesIO(image_content))

# %%
display(image_content)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=100x100 at 0x7FD8CD250A60>

# %% [markdown]
# <div style="background-color: #506AB9;" >
#     <h3 style="margin: auto; padding: 20px; color:#fff; ">4.1. Resizing</h3>
# </div>

# %%
image_resized = image_content.resize([224, 224])

# %%
display(image_resized)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FD8CD249850>

# %% [markdown]
# <div style="background-color: #506AB9;" >
#     <h3 style="margin: auto; padding: 20px; color:#fff; ">4.2. Noise reduction</h3>
# </div>

# %%
image_noise_reduction = noise_reduction(image_resized)

# %%
# Initializing each figure/plot
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5)) 

ax1.imshow(image_resized)
ax1.set_title("image", fontsize=14, fontweight="bold")
ax1.grid(None)
ax1.axis("off")

ax2.imshow(image_noise_reduction)
ax2.set_title("Image with noise reduced", fontsize=14, fontweight="bold")
ax2.grid(None)
ax2.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color: #506AB9;" >
#     <h3 style="margin: auto; padding: 20px; color:#fff; ">4.3. Adjusting contrast and brightness</h3>
# </div>

# %%
image_contrast_and_brightness = np.array(ImageOps.equalize(ImageOps.autocontrast(image_noise_reduction, cutoff=5)))

# %%
show_image_and_histogram(image_noise_reduction, image_contrast_and_brightness)

# %% [markdown]
# <div style="background-color: #506AB9;" >
#     <h3 style="margin: auto; padding: 20px; color:#fff; ">4.4. Gaussian Blur</h3>
# </div>

# %%
image_gaussian_blur = gaussian_blur(image_contrast_and_brightness)

# %%
# Initializing each figure/plot
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5)) 

ax1.imshow(image_contrast_and_brightness)
ax1.set_title("image", fontsize=14, fontweight="bold")
ax1.grid(None)
ax1.axis("off")

ax2.imshow(image_gaussian_blur)
ax2.set_title("Image with Gaussin Blur", fontsize=14, fontweight="bold")
ax2.grid(None)
ax2.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color: #506AB9;" >
#     <h3 style="margin: auto; padding: 20px; color:#fff; ">4.5. Image to array</h3>
# </div>

# %%
image_arr = img_to_array(image_gaussian_blur)
image_arr = preprocess_input(image_arr)
plt.imshow(image_arr)
plt.axis("off")
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# <div style="background-color: #506AB9;" >
#     <h2 style="margin: auto; padding: 20px; color:#fff; ">4. Featurization for transfer learning</h2>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <p>So far, we could read the images from out bucket (S3) through Spark.<br>
#     Now, we are going to extract the features based on a pre-trained TensorFlow model. <br>
#     To do that, We are going to base ourselves on the approach made by <a href="https://docs.databricks.com/applications/machine-learning/preprocess-data/transfer-learning-tensorflow.html", target="blank">Databricks</a></p>
# </div>

# %%
model = ResNet50(include_top=False)

bc_model_weights = spark.sparkContext.broadcast(model.get_weights())
# Out:
# 2022-03-13 07:37:12.868002: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-03-13 07:37:12.868063: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (ip-172-31-80-208): /proc/driver/nvidia/version does not exist
# 2022-03-13 07:37:12.868424: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def model_fn():
    """
    Returns a ResNet50 model with top layer removed and broadcasted pretrained weights.
    """
    
    model = ResNet50(weights=None, include_top=False)
    model.set_weights(bc_model_weights.value)
    
    return model

# %%
def preprocess(content):
    """
    Preprocesses raw image bytes for prediction.
    """
    
    img = Image.open(io.BytesIO(content)).resize([224, 224])
    
    # preprocessing image
    img = noise_reduction(img)
    img = np.array(ImageOps.equalize(ImageOps.autocontrast(img, cutoff=5)))
    img = gaussian_blur(img)
    
    arr = img_to_array(img)
    
    return preprocess_input(arr)

# %%
def featurize_series(model, content_series):
    """
    Featurize a pd.Series of raw images using the input model.
    :return: a pd.Series of image features
    """
    
    input = np.stack(content_series.map(preprocess))
    preds = model.predict(input)
    
    # For some layers, output features will be multi-dimensional tensors.
    # We flatten the feature tensors to vectors for easier storage in Spark DataFrames.
    output = [p.flatten() for p in preds]
    
    return pd.Series(output)

# %%
@pandas_udf('array<float>', PandasUDFType.SCALAR_ITER)
def featurize_udf(content_series_iter):
    """
    This method is a Scalar Iterator pandas UDF wrapping our featurization function.
    The decorator specifies that this returns a Spark DataFrame column of type ArrayType(FloatType).
    
    :param content_series_iter: This argument is an iterator over batches of data, where each batch
                                is a pandas Series of image data.
    """
    
    # With Scalar Iterator pandas UDFs, we can load the model once and then re-use it
    # for multiple data batches.  This amortizes the overhead of loading big models.
    model = model_fn()
    for content_series in content_series_iter:
        yield featurize_series(model, content_series)
# Out:
# /opt/spark/python/pyspark/sql/pandas/functions.py:383: UserWarning: In Python 3.6+ and Spark 3.0+, it is preferred to specify type hints for pandas UDF instead of specifying pandas UDF type which will be deprecated in the future releases. See SPARK-28264 for more details.
#   warnings.warn(

# %%
df_features = df_images.repartition(16).select(col("path"), col("category"), featurize_udf("content").alias("features"))
df_features.printSchema()
# Out:
# root
#  |-- path: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- features: array (nullable = true)
#  |    |-- element: float (containsNull = true)

# %%
df_features.show()
# Out:
# 2022-03-13 07:37:36.469320: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/ubuntu/.local/lib/python3.8/site-packages/cv2/../../lib64:/home/ubuntu/.local/lib/python3.8/site-packages/cv2/../../lib64:
# 2022-03-13 07:37:36.469358: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-03-13 07:37:39.122387: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-03-13 07:37:39.122434: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (ip-172-31-80-208): /proc/driver/nvidia/version does not exist
# 2022-03-13 07:37:39.122775: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-13 07:37:43.479595: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 19267584 exceeds 10% of free system memory.
# 2022-03-13 07:37:43.619836: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 19267584 exceeds 10% of free system memory.
# 2022-03-13 07:37:43.644202: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 19961856 exceeds 10% of free system memory.
# 2022-03-13 07:37:43.664523: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 19267584 exceeds 10% of free system memory.
# 2022-03-13 07:37:43.687303: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 19267584 exceeds 10% of free system memory.
# 2022-03-13 07:37:47.402365: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/ubuntu/.local/lib/python3.8/site-packages/cv2/../../lib64:/home/ubuntu/.local/lib/python3.8/site-packages/cv2/../../lib64:
# 2022-03-13 07:37:47.402401: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-03-13 07:37:53.963728: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-03-13 07:37:53.963773: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (ip-172-31-80-208): /proc/driver/nvidia/version does not exist
# 2022-03-13 07:37:53.964761: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-13 07:37:58.709681: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 19267584 exceeds 10% of free system memory.
# 2022-03-13 07:37:58.788974: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 19267584 exceeds 10% of free system memory.
# 2022-03-13 07:37:58.819691: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 19961856 exceeds 10% of free system memory.
# 2022-03-13 07:37:58.845970: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 19267584 exceeds 10% of free system memory.
# 2022-03-13 07:37:58.879389: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 19267584 exceeds 10% of free system memory.
# [Stage 11:===========================================>              (3 + 1) / 4]
# +--------------------+----------+--------------------+
# |                path|  category|            features|
# +--------------------+----------+--------------------+
# |s3a://oc-p8-bucke...| Raspberry|[0.0, 0.0, 0.0, 0...|
# |s3a://oc-p8-bucke...|      Kiwi|[0.0, 0.0, 0.0, 0...|
# |s3a://oc-p8-bucke...|  Maracuja|[0.0, 0.0, 0.0, 0...|
# |s3a://oc-p8-bucke...|  Maracuja|[0.0, 0.0, 0.0, 0...|
# |s3a://oc-p8-bucke...|     Lemon|[0.0, 0.0, 0.0, 0...|
# |s3a://oc-p8-bucke...|     Lemon|[0.0, 0.0, 0.0, 0...|
# |s3a://oc-p8-bucke...|      Kiwi|[0.0, 0.0, 0.0, 0...|
# |s3a://oc-p8-bucke...|Watermelon|[0.0, 0.0, 0.0, 0...|
# |s3a://oc-p8-bucke...|     Lemon|[0.0, 0.0, 0.0, 0...|
# |s3a://oc-p8-bucke...|   Avocado|[0.0, 0.0, 0.0, 0...|
# |s3a://oc-p8-bucke...|    Banana|[0.0, 0.0, 0.0, 0...|
# |s3a://oc-p8-bucke...|    Banana|[0.0, 0.0, 0.0, 0...|
# |s3a://oc-p8-bucke...| Raspberry|[0.0, 0.0, 0.0, 0...|
# |s3a://oc-p8-bucke...| Raspberry|[0.0, 0.0, 0.0, 0...|
# |s3a://oc-p8-bucke...|   Apricot|[0.0, 0.0, 0.0, 0...|
# |s3a://oc-p8-bucke...|   Apricot|[0.0, 0.0, 0.0, 0...|
# |s3a://oc-p8-bucke...|     Lemon|[0.0, 0.0, 0.0, 0...|
# |s3a://oc-p8-bucke...|   Apricot|[0.0, 0.0, 0.0, 0...|
# |s3a://oc-p8-bucke...|Watermelon|[0.0, 0.0, 0.0, 0...|
# |s3a://oc-p8-bucke...|Watermelon|[0.0, 0.0, 0.0, 0...|
# +--------------------+----------+--------------------+
# only showing top 20 rows

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <p>We have achieved to make the feature extraction.</p>
# </div>

# %% [markdown]
# <div style="background-color: #506AB9;" >
#     <h2 style="margin: auto; padding: 20px; color:#fff; ">5. PCA - Principal Components Analysis</h2>
# </div>

# %%
to_vector = udf(lambda x: Vectors.dense(x), VectorUDT())
df_features = df_features.select(col("path"),  col("category"), to_vector(df_features["features"]).alias("features"))

# %%
pca = PCA(k=7, inputCol="features", outputCol="pca_features")

# %%
model_pca = pca.fit(df_features)

# %%
pca_features = model_pca.transform(df_features)

# %%
pca_features.printSchema()
# Out:
# root
#  |-- path: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- features: vector (nullable = true)
#  |-- pca_features: vector (nullable = true)

# %%
pca_features.show(8)
# Out:
# 22/03/13 08:41:55 WARN DAGScheduler: Broadcasting large task binary with size 5.4 MiB
# 2022-03-13 08:42:01.915146: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/ubuntu/.local/lib/python3.8/site-packages/cv2/../../lib64:/home/ubuntu/.local/lib/python3.8/site-packages/cv2/../../lib64:
# 2022-03-13 08:42:01.915190: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-03-13 08:42:11.340100: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-03-13 08:42:11.340153: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (ip-172-31-80-208): /proc/driver/nvidia/version does not exist
# 2022-03-13 08:42:11.341315: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 22/03/13 08:42:21 WARN DAGScheduler: Broadcasting large task binary with size 5.4 MiB
# [Stage 124:>                                                        (0 + 1) / 1]
# +--------------------+----------+--------------------+--------------------+
# |                path|  category|            features|        pca_features|
# +--------------------+----------+--------------------+--------------------+
# |s3a://oc-p8-bucke...| Raspberry|[0.0,0.0,0.0,0.0,...|[139.847600016036...|
# |s3a://oc-p8-bucke...|      Kiwi|[0.0,0.0,0.0,0.0,...|[-160.07580122351...|
# |s3a://oc-p8-bucke...|  Maracuja|[0.0,0.0,0.0,0.0,...|[-266.87345970262...|
# |s3a://oc-p8-bucke...|  Maracuja|[0.0,0.0,0.0,0.0,...|[-251.04512951045...|
# |s3a://oc-p8-bucke...|     Lemon|[0.0,0.0,0.0,0.0,...|[-144.02005237071...|
# |s3a://oc-p8-bucke...|     Lemon|[0.0,0.0,0.0,0.0,...|[-129.89664558876...|
# |s3a://oc-p8-bucke...|      Kiwi|[0.0,0.0,0.0,0.0,...|[-106.52030715756...|
# |s3a://oc-p8-bucke...|Watermelon|[0.0,0.0,0.0,0.0,...|[-21.861729215902...|
# +--------------------+----------+--------------------+--------------------+
# only showing top 8 rows

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <p>Let's plot the % of inertia (variance) based on the principal components.</p>
# </div>

# %%
scree = model_pca.explainedVariance.cumsum()

fig = plt.subplots(figsize=(8, 5))
sns.set_context(context="notebook", rc={"lines.linewidth": 3}, font_scale=0.8)
sns.lineplot(x=[i for i in range(8)], y=np.insert(scree, 0, 0)*100, color="orangered")
plt.xlabel("Principal components", size=12)
plt.ylabel("% of inertia", size=12)
plt.title("Scree of eigenvalues", size=20)
plt.ylim(0, 100)
plt.xlim(left=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <p>Let's save the PCA results as *.csv into our S3.</p>
# </div>

# %%
df_final = pca_features.select("path", "category", "pca_features")

# %%
df_final_pd = df_final.toPandas()

# %%
df_final_pd.to_csv("s3a://{}/{}/{}".format(BUCKET, RESULT, "P7_PCA_result_03132022.csv"))
